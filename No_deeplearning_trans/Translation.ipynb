# %%
import csv
import json
import fitz  # PyMuPDF
import ocrmypdf
import os
from pathlib import Path
import time
import logging
from deep_translator import GoogleTranslator
from langdetect import detect, DetectorFactory
from PyPDF2 import PdfReader, PdfWriter, Transformation
import copy
import string
import os
import shutil

# %%
# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.FileHandler("ocr_recovery.log"),
        logging.StreamHandler()
    ]
)

# %%
def find_max_csv_field_size():
    """Find the maximum CSV field size limit using binary search"""
    max_int = 2147483647  # 2^31-1
    min_int = 1024
    
    while min_int < max_int:
        try:
            mid = (min_int + max_int + 1) // 2
            csv.field_size_limit(mid)
            min_int = mid
        except OverflowError:
            max_int = mid - 1
    
    return min_int

# %%
# Safely set maximum CSV field size limit
csv.field_size_limit(find_max_csv_field_size())
# Out:
# 2147483647

# %%
def int_to_rgb(color_int):
    """Convert integer color to RGB tuple."""
    if color_int < 0:
        color_int = color_int & 0xFFFFFFFF

    a = (color_int >> 24) & 0xFF
    r = (color_int >> 16) & 0xFF
    g = (color_int >> 8) & 0xFF
    b = color_int & 0xFF

    if (a == 0):
        a = 255

    return [r, g, b, a]

# %%
def normalize_spaced_text(text):
    """
    Normalize text with excessive spacing between characters,
    commonly found in headers like "F I N A N C I A L  S T A T E M E N T S" or ""
    """
    # Check if text has consistent spacing pattern (every character followed by space)
    if len(text) > 3 and all(text[i] == ' ' for i in range(1, len(text), 2)):
        # Join characters by removing spaces
        return ''.join(text[i] for i in range(0, len(text), 2))
    
    # Check if text has spaces between all characters
    if len(text) > 3 and ' ' in text:
        # Count spaces vs non-spaces
        spaces = text.count(' ')
        non_spaces = len(text) - spaces
        
        # If the ratio of spaces to characters is high (e.g., spaces >= characters)
        if spaces >= non_spaces - 1:
            text_split = text.split(' ')
            text_split = [' ' if char == '' else char for char in text_split]
            return ''.join(text_split)
    
    # Return original if no patterns match
    return text

# %%
def apply_ocr_to_pdf(input_path, output_dir):
    """Apply OCR to a PDF file using OCRmyPDF"""
    # Create OCR file in data/test/PDF_ocr directory
    output_path = output_dir / f"{input_path.stem}.ocr.pdf"

    try:
        languages = [
            "chi_sim",  # Simplified Chinese
            "chi_tra",  # Traditional Chinese
            "vie",      # Vietnamese
            "eng",      # English
            "jpn",      # Japanese
            "kor",      # Korean
            "fra",      # French
            "deu",      # German
            "spa",      # Spanish
            "rus"       # Russian
        ]

        # Run OCR with multiple language support
        ocrmypdf.ocr(
            input_path,
            output_path,
            language="+".join(languages),
            deskew=True,
            clean=False,
            optimize=0,
            output_type='pdf',  # Changed from 'pdfa' to 'pdf' to retain original color space
            skip_text=True,
            progress_bar=True,
            color_conversion_strategy='UseDeviceIndependentColor',
        )
        logging.info(f"OCR completed: {output_path}")
        return output_path
    except Exception as e:
        logging.error(f"OCR error: {str(e)}")
        return None

# %%
def map_language_code_for_deep_translator(lang_code):
    mapping = {
        "zh-cn": "zh-CN",
        "zh-hans": "zh-CN",
        "zh-tw": "zh-TW",
        'zh-hant': 'zh-TW',
        'zh': 'zh-CN',     # Default Chinese to Simplified
        'jw': 'jv',        # Javanese
        'iw': 'he',        # Hebrew
        'in': 'id',        # Indonesian
        'ceb': 'tl',       # Adjust Cebuano to use Tagalog
    }

    return mapping.get(lang_code, lang_code)

# %%
def batch_translate_text(texts_with_langs, target='vi', batch_size=25, delay=0):
    """
    Translate a batch of texts with rate limiting.
    
    Args:
        texts: List of texts to translate
        source: Source language code
        target: Target language code
        batch_size: Number of texts to translate in one batch
        delay: Delay between batches in seconds
        
    Returns:
        List of translated texts
    """
    results = [""] * len(texts_with_langs)

    # Group text by detected source language
    lang_groups = {}
    for text, lang, orig_idx in texts_with_langs:
        if not lang in lang_groups:
            lang_groups[lang] = []
        lang_groups[lang].append((text, orig_idx))

    for source_lang, texts_with_indices in lang_groups.items():
        if source_lang == target:
            for text, orig_idx in texts_with_indices:
                results[orig_idx] = text
            continue

        texts = [t[0] for t in texts_with_indices]
        indices = [t[1] for t in texts_with_indices]

        # Create translator for this language
        translator = GoogleTranslator(source=source_lang, target=target)

        translated_batch = []

        for i in range(0, len(texts), batch_size):
            batch = texts[i:min(i + batch_size, len(texts))]
            
            # Process each text in the current batch
            batch_results = []
            for text in batch:
                try:    
                    translated = translator.translate(text)
                    batch_results.append(translated)
                    
                except Exception as e:
                    logging.warning(f"Translation error: {str(e)[:100]}...")
                    # Return original text on error
                    batch_results.append(text)
                    
                    # Handle rate limiting - increase delay and reduce batch size
                    if "429" in str(e) or "too many requests" in str(e).lower():
                        logging.info(f"Rate limit hit. Increasing delay to {delay*2}s and reducing batch size.")
                        delay *= 2
                        batch_size = max(1, batch_size // 2)
                        time.sleep(5)  # Additional pause after hitting rate limit
            
            translated_batch.extend(batch_results)
            
            # Add delay between batches
            if i + batch_size < len(texts):
                time.sleep(delay)

        # Put translated texts back in their original positions
        for translated_text, orig_idx in zip(translated_batch, indices):
            results[orig_idx] = translated_text
            
    return results

# %%
def translate_cells(cells, target='vi'):
    """
    Translate text in cells from source language to target language.
    
    Args:
        cells: List of cell dictionaries with text
        source: Source language code
        target: Target language code
        
    Returns:
        List of cell dictionaries with translated text
    """
    # Extract all texts and detect languages
    texts_with_langs = []
    for i, cell in enumerate(cells):
        if cell.get("text"):
            try:
                # Detect language for each text
                lang = detect(cell["text"])
                # Map language code for deep_translator
                mapped_lang = map_language_code_for_deep_translator(lang)
                # Store original language in cell
                texts_with_langs.append((cell["text"], mapped_lang, i))
            except Exception as e:
                logging.warning(f"Language detection error: {str(e)[:100]}... Using 'en' as fallback.")
                texts_with_langs.append((cell["text"], "en", i))
    
    logging.info(f"Translating {len(texts_with_langs)} text segments to {target}...")

    lang_counts = {}
    for _, lang, _ in texts_with_langs:
        lang_counts[lang] = lang_counts.get(lang, 0) + 1
    
    logging.info("Detected languages:")
    for lang, count in lang_counts.items():
        logging.info(f"  - {lang}: {count} segments")
    
    # Perform batch translation
    translated_texts = batch_translate_text(texts_with_langs, target)
    
    # Map translated texts back to cells
    text_index = 0
    for cell in cells:
        if cell.get("text"):
            cell["text_vi"] = translated_texts[text_index]
            text_index += 1
    
    return cells

# %%
def clean_text(text):
    """Clean text by removing/replacing non-printable characters"""
    if not isinstance(text, str):
        return text
        
    # Replace common problematic Unicode characters
    replacements = {
        '\u0000': '',  # NULL
        '\u0001': '',  # START OF HEADING
        '\u0002': '',  # START OF TEXT
        '\u0003': '',  # END OF TEXT
        '\u0004': '',  # END OF TRANSMISSION
        '\u0005': '',  # ENQUIRY
        '\u0006': '',  # ACKNOWLEDGE
        '\u0007': '',  # BELL
        '\u0014': '',  # DEVICE CONTROL FOUR
        '\u0015': '',  # NEGATIVE ACKNOWLEDGE
        '\ufffd': '',  # REPLACEMENT CHARACTER (�)
        '\u200b': '',  # ZERO WIDTH SPACE
        '\u200e': '',  # LEFT-TO-RIGHT MARK
        '\u200f': '',  # RIGHT-TO-LEFT MARK
        '\ufeff': '',  # ZERO WIDTH NO-BREAK SPACE
    }
    
    # Apply replacements
    for char, replacement in replacements.items():
        text = text.replace(char, replacement)
    
    # Filter out any remaining control characters
    return ''.join(char for char in text if ord(char) >= 32 or char in '\n\r\t')

# %%
def extract_pdf_info(pdf_path):
    """Extract text and formatting information from a PDF file"""
    doc = fitz.open(pdf_path)
    cells = []
    
    try:
        for page_num, page in enumerate(doc, start=1):
            blocks = page.get_text("dict")["blocks"]
            for block in blocks:
                for line in block.get("lines", []):
                    for span in line.get("spans", []):
                        span["text"] = clean_text(span["text"]).strip()
                        # Skip empty spans
                        if not span["text"]:
                            continue

                        # Normalize text with excessive spacing
                        normalized_text = normalize_spaced_text(span["text"])

                        cell = {
                            "x": span["bbox"][0],
                            "y": span["bbox"][1],
                            "width": span["bbox"][2] - span["bbox"][0],     # width
                            "height": span["bbox"][3] - span["bbox"][1],    # height
                            "text": normalized_text,
                            "font": {
                                "color": int_to_rgb(span["color"]),
                                "name": span["font"],
                                "size": int(span["size"]),
                            },
                            "text_vi": normalized_text  # Will be translated later
                        }
                        cells.append(cell)
    except Exception as e:
        logging.error(f"Error extracting text from {pdf_path}: {str(e)}")
    finally:
        doc.close()
    
    # Add translation step
    if cells:
        try:
            logging.info(f"Translating {len(cells)} cells to Vietnamese...")
            cells = translate_cells(cells, target='vi')
            logging.info(f"Translation complete for {len(cells)} cells")
        except Exception as e:
            logging.error(f"Translation error: {str(e)}")
            # Continue with untranslated text

    # Final null check before returning
    for cell in cells:
        if cell.get("text_vi") is None:
            cell["text_vi"] = cell.get("text", "")  # Use original or empty string

    return {"cells": cells}

# %%
def get_file_ids(file_path):
    """Get expected file IDs from sample submission file"""
    if not file_path.exists():
        logging.warning(f"Sample submission file not found: {file_path}")
        return set()  # Return empty set if file doesn't exist
        
    expected_ids = set()
    try:
        with open(file_path, 'r', newline='', encoding='utf-8') as f:
            reader = csv.reader(f)
            next(reader)  # Skip header
            for row in reader:
                if row and row[0]:  # Check if row exists and has an ID
                    expected_ids.add(row[0])
        
        logging.info(f"Found {len(expected_ids)} expected file IDs")
        return expected_ids
    except Exception as e:
        logging.error(f"Error reading sample submission: {e}")
        return set()

# %%
def scale_pdf(input_path, output_path, target_width=1025, target_height=1025):
    """
    Scale a PDF to the target dimensions ensuring both page size and content are scaled.

    Args:
        input_path (str): Path to the input PDF file
        output_path (str): Path where the scaled PDF will be saved
        target_width (int): Target width in pixels (default: 1025)
        target_height (int): Target height in pixels (default: 1025)
    """
    # Read the original PDF
    reader = PdfReader(input_path)
    writer = PdfWriter()

    # Convert target dimensions from pixels to points (72 points = 1 inch)
    # Assuming 72 DPI resolution
    target_width_pts = target_width
    target_height_pts = target_height

    # Process each page
    for page_num in range(len(reader.pages)):
        # Get the original page
        original_page = reader.pages[page_num]

        # Get original page dimensions
        mediabox = original_page.mediabox
        orig_width = float(mediabox.width)
        orig_height = float(mediabox.height)

        # Calculate scaling factors
        width_scale = target_width_pts / orig_width
        height_scale = target_height_pts / orig_height

        # Create a copy of the page to work with
        page = copy.deepcopy(original_page)

        # Apply scaling transformation to the content
        transform = Transformation().scale(width_scale, height_scale)
        page.add_transformation(transform)

        # Update the mediabox to the new dimensions
        # PyPDF2 uses a coordinate system with (0,0) at the bottom left
        page.mediabox.lower_left = (0, 0)
        page.mediabox.upper_right = (target_width_pts, target_height_pts)

        # Also update cropbox and trimbox if they exist
        if "/CropBox" in page:
            page.cropbox.lower_left = (0, 0)
            page.cropbox.upper_right = (target_width_pts, target_height_pts)

        if "/TrimBox" in page:
            page.trimbox.lower_left = (0, 0)
            page.trimbox.upper_right = (target_width_pts, target_height_pts)

        if "/ArtBox" in page:
            page.artbox.lower_left = (0, 0)
            page.artbox.upper_right = (target_width_pts, target_height_pts)

        if "/BleedBox" in page:
            page.bleedbox.lower_left = (0, 0)
            page.bleedbox.upper_right = (target_width_pts, target_height_pts)

        # Add the scaled page to the output PDF
        writer.add_page(page)

    # Write the result to the output file
    with open(output_path, "wb") as output_file:
        writer.write(output_file)

    print(f"PDF scaled successfully to {target_width}x{target_height}.")
    print(f"Both page dimensions and content have been scaled. Saved to {output_path}")

# %%
def process_all_pdfs(pdf_dir, scaled_dir, ocr_dir, output_csv):
    # Get all pdf files from pdf_dir
    pdf_files = list(pdf_dir.glob("*.pdf"))
    total_files = len(pdf_files)

    # Scale all PDFs to COCO standard size if needed
    scaled_pdf_paths = []
    for i, pdf_file in enumerate(pdf_files, 1):

        output_pdf_path = scaled_dir / f"{pdf_file.stem}.coco_standard.pdf"
        scaled_pdf_paths.append(output_pdf_path)
        
        if not output_pdf_path.exists():
            print(f"[{i}/{total_files}] Scaling: {pdf_file.name}")
            scale_pdf(pdf_file, output_pdf_path)
        else:
            print(f"[{i}/{total_files}] Already scaled: {pdf_file.name}")

    # Create CSV file with header if it doesn't exist
    csv_exists = output_csv.exists()
    if not csv_exists:
        with open(output_csv, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(["id", "solution"])
    
    # Keep track of already processed files
    processed_ids = set()
    if csv_exists:
        with open(output_csv, "r", newline="", encoding="utf-8") as f:
            reader = csv.reader(f)
            # Check if the file has any rows before trying to skip the header
            try:
                next(reader)  # Skip header
                for row in reader:
                    if row:
                        processed_ids.add(row[0])
                print(f"Found {len(processed_ids)} already processed files in submission.csv")
            except StopIteration:
                # File exists but is empty or only contains header
                print("Existing submission.csv appears to be empty. Starting fresh.")
                # Reset the file with just a header
                with open(output_csv, "w", newline="", encoding="utf-8") as f_reset:
                    writer = csv.writer(f_reset)
                    writer.writerow(["id", "solution"])
        print(f"Found {len(processed_ids)} already processed files in submission.csv")

    # Process each PDF and append to CSV immediately
    for idx, scaled_pdf_file in enumerate(scaled_pdf_paths, 1):
        # Extract file ID from filename
        file_id = scaled_pdf_file.stem.replace(".coco_standard", "")
        
        # Skip if already processed
        if file_id in processed_ids:
            print(f"[{idx}/{total_files}] Skipping already processed: {file_id}")
            continue
            
        print(f"[{idx}/{total_files}] Processing: {scaled_pdf_file.name}")
        
        try:
            # Apply OCR to the PDF
            ocr_pdf_file = apply_ocr_to_pdf(scaled_pdf_file, ocr_dir)
            if not ocr_pdf_file:
                logging.error(f"OCR failed for {file_id}")
                continue

            # Process PDF and extract cells
            output = extract_pdf_info(ocr_pdf_file)
            cells = output.get("cells", [])
            
            # Append result to CSV immediately
            with open(output_csv, "a", newline="", encoding="utf-8") as f:
                writer = csv.writer(f, quoting=csv.QUOTE_MINIMAL)
                json_str = json.dumps(cells, ensure_ascii=False)
                json_str = clean_text(json_str)
                writer.writerow([file_id, json_str])
                
            processed_ids.add(file_id)
            print(f"Saved result for {file_id} to {output_csv}")
            
        except Exception as e:
            print(f"Error processing {file_id}: {str(e)}")
            continue

    print(f"Processing complete! {len(processed_ids)} files processed.")

# %%
def document_translation(file_id, rescale = False):
    pdf_path = './' + file_id + '.pdf' # Original pdf file path
    working_folder = './' + file_id # Temporary working folder
    file_csv = os.path.join(working_folder, file_id + '.csv') # .csv file file in temporary folder
    file_pdf = os.path.join(working_folder, file_id + '.coco_standard.ocr.pdf') # resize pdf
    output_pdf_path = './translation_' + file_id + '.pdf' # output pdf path

    if os.path.exists(working_folder):
        shutil.rmtree(working_folder)
        print(f"Deleted existing working folder: {working_folder}")


    # Extract the file name without extension
    file_name = os.path.splitext(os.path.basename(pdf_path))[0]

    # Create a folder with the same name
    folder_path = os.path.join(os.path.dirname(pdf_path), file_name)
    os.makedirs(folder_path, exist_ok=True)

    # Move the PDF to the new folder
    new_pdf_path = os.path.join(folder_path, os.path.basename(pdf_path))
    shutil.copy(pdf_path, new_pdf_path)

    # File paths
    pdf_dir = Path(file_id)  # Directory with original PDF files
    scaled_dir = Path(file_id)
    ocr_dir = Path(file_id)

    output_csv = Path(file_csv)

    # Ensure necessary directories exist
    os.makedirs(pdf_dir, exist_ok=True)
    os.makedirs(scaled_dir, exist_ok=True)
    os.makedirs(ocr_dir, exist_ok= True)

    process_all_pdfs(pdf_dir, scaled_dir, ocr_dir, output_csv)

    # Define the path to the custom font
    font_file_path = "./" + "Roboto.ttf"

    # Define file paths (replace these with your actual paths if not using variables)
    csv_file_path = file_csv  # Replace with your CSV file path

    # Step 1: Read the CSV file
    try:
        with open(csv_file_path, 'r', encoding='utf-8') as f:
            reader = csv.DictReader(f)
            data = list(reader)  # Convert the reader to a list of dictionaries
        print(f"Successfully read {len(data)} rows from {csv_file_path}")
    except FileNotFoundError:
        print(f"Error: {csv_file_path} not found")
        exit(1)

    # Step 2: Open the PDF
    try:
        doc = fitz.open(file_pdf)

        doc_size = fitz.open(pdf_path)

        page = doc[0]  # Assuming the text is on the first page (page 1)
        page_size = doc_size[0]

        page_rect = page_size.rect
        page_width = page_rect.width
        page_height = page_rect.height
        print(f"Opened {pdf_path}, size: {page_width} x {page_height}")
    except Exception as e:
        print(f"Error opening PDF: {e}")
        exit(1)

    # Step 3: Process the CSV data and replace text in the PDF
    for item in data:
        try:
            # Parse the 'solution' string into a list of dictionaries
            ocr_data = json.loads(item['solution'])
            print(f"Processing item with id: {item['id']}, {len(ocr_data)} entries")
            
            for entry in ocr_data:
                x = entry["x"]
                y = entry["y"]
                width = entry["width"]
                height = entry["height"]
                text_vi = entry["text_vi"]
                font_size = entry["font"]["size"]
                font_name = 'Roboto' # entry["font"]["name"]

                # Adjust y-coordinate for PyMuPDF (bottom-left origin)
                y_adjusted = y
                rect = fitz.Rect(x, y_adjusted, x + width, y_adjusted + height)

                # Cover the original text with a white rectangle
                page.draw_rect(rect, color=[1, 1, 1], fill=[1, 1, 1]) # color=[0, 0, 0]

                # Initialize the font object from file
                font = fitz.Font(fontname=font_name, fontfile=font_file_path)

                # Measure and shrink font to fit the box
                text_width = font.text_length(text_vi, fontsize=font_size)
                while text_width > width and font_size > 1:
                    font_size -= 1
                    text_width = font.text_length(text_vi, fontsize=font_size)
                    
                # Adjust the vertical position (if needed) to fit inside the rectangle
                y_text_pos = y_adjusted + (height / 2)  # Vertically center the text in the box
                
                #y_text_pos = y_text_pos + (font_size / 2)  # Adjust y position to place text in the middle

                if (font_size >= 2):
                    font_size -= 1
                
                # Insert the translated text (text_vi)
                page.insert_text(
                    (x, y_text_pos),  # x, y position of the text
                    text_vi,
                    fontsize=font_size,
                    fontname=font_name,
                    fontfile=font_file_path,
                    encoding='utf-16',  # Use UTF-8 encoding to support Vietnamese characters
                    fill_opacity=1,  # Fill opacity
                    stroke_opacity=1,  # Stroke opacity
                    border_width=1  # Border thickness
                )
                print(f"Replaced text at ({x}, {y}) with '{text_vi}'")
        except json.JSONDecodeError as e:
            print(f"Error parsing 'solution' for id {item['id']}: {e}")
        except Exception as e:
            print(f"Error processing entry: {e}")

    # Step 4: Save the modified PDF
    try:
        doc.save(output_pdf_path)
        doc.close()
        if rescale: scale_pdf(output_pdf_path, output_pdf_path, page_width, page_height)
        print(f"PDF modified and saved as {output_pdf_path}")

        # Clean up working folder
        shutil.rmtree(working_folder)
        print(f"Deleted temporary folder: {working_folder}")

    except Exception as e:
        print(f"Error saving PDF: {e}")

# %%
'''
8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01

8a27ba3644da19b268f2d88f59eb455ba104dd262c4eda42674824a53b6932f6

8a112f652c793830a0911f1bf81fe0a74cb2e25555570bcc0d0c9e20f29538ea
'''

document_translation('8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01', rescale=True)
# Out:
# [1/1] Scaling: 8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.pdf
# PDF scaled successfully to 1025x1025.
# Both page dimensions and content have been scaled. Saved to 8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01\8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.coco_standard.pdf
# [1/1] Processing: 8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.coco_standard.pdf
# d:\Users\envs\visualize\Lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2025-04-13 10:29:26,918 [INFO] skipping all processing on this page
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2025-04-13 10:29:26,942 [INFO] Postprocessing...
# d:\Users\envs\visualize\Lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 2025-04-13 10:29:27,080 [INFO] Image optimization ratio: 1.00 savings: 0.0%
# 2025-04-13 10:29:27,085 [INFO] Total file size ratio: 1.00 savings: -0.2%
# 2025-04-13 10:29:27,172 [INFO] OCR completed: 8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01\8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.coco_standard.ocr.pdf
# 2025-04-13 10:29:27,222 [INFO] Translating 299 cells to Vietnamese...
# 2025-04-13 10:29:27,227 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,367 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,442 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,532 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,613 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,636 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,672 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,683 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,683 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,732 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,744 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:27,912 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,047 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,314 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,328 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,328 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,332 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,397 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,524 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,670 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,886 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,886 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:28,895 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,042 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,049 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,202 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,272 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,276 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,292 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,306 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,355 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,392 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,505 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,521 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,652 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,868 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,882 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:29,892 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:30,082 [WARNING] Language detection error: No features in text.... Using 'en' as fallback.
# 2025-04-13 10:29:30,154 [INFO] Translating 299 text segments to vi...
# 2025-04-13 10:29:30,154 [INFO] Detected languages:
# 2025-04-13 10:29:30,154 [INFO]   - de: 31 segments
# 2025-04-13 10:29:30,154 [INFO]   - en: 200 segments
# 2025-04-13 10:29:30,162 [INFO]   - af: 16 segments
# 2025-04-13 10:29:30,167 [INFO]   - lv: 2 segments
# 2025-04-13 10:29:30,167 [INFO]   - es: 2 segments
# 2025-04-13 10:29:30,170 [INFO]   - cy: 8 segments
# 2025-04-13 10:29:30,172 [INFO]   - ro: 3 segments
# 2025-04-13 10:29:30,172 [INFO]   - ca: 2 segments
# 2025-04-13 10:29:30,172 [INFO]   - id: 3 segments
# 2025-04-13 10:29:30,172 [INFO]   - pt: 9 segments
# 2025-04-13 10:29:30,172 [INFO]   - sv: 1 segments
# 2025-04-13 10:29:30,179 [INFO]   - nl: 3 segments
# 2025-04-13 10:29:30,182 [INFO]   - it: 4 segments
# 2025-04-13 10:29:30,186 [INFO]   - tl: 3 segments
# 2025-04-13 10:29:30,187 [INFO]   - vi: 1 segments
# 2025-04-13 10:29:30,187 [INFO]   - fr: 4 segments
# 2025-04-13 10:29:30,187 [INFO]   - pl: 1 segments
# 2025-04-13 10:29:30,187 [INFO]   - lt: 1 segments
# 2025-04-13 10:29:30,193 [INFO]   - fi: 2 segments
# 2025-04-13 10:29:30,193 [INFO]   - no: 1 segments
# 2025-04-13 10:29:30,195 [INFO]   - da: 2 segments
# 2025-04-13 10:32:15,862 [INFO] Translation complete for 299 cells
# Saved result for 8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01 to 8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01\8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.csv
# Processing complete! 1 files processed.
# Successfully read 1 rows from ./8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01\8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.csv
# Opened ./8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.pdf, size: 612.0 x 792.0
# Processing item with id: 8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01, 299 entries
# Replaced text at (434.1009216308594, 67.29785919189453) with 'Hoa Kỳ 9.958.775 B2'
# Replaced text at (300.18096923828125, 87.25953674316406) with '33'
# Replaced text at (129.39788818359375, 105.68905639648438) with 'Hợp chất polymer tốt nhất bao gồm ít nhất một loại'
# Replaced text at (129.68260192871094, 119.04513549804688) with 'của'
# Replaced text at (148.708740234375, 119.04513549804688) with 'Lặp lại đơn vị có nhóm hydroxyl phenolic. Các'
# Replaced text at (129.42237854003906, 132.71286010742188) with 'Lặp lại đơn vị có nhóm hydroxyl phenolic'
# Replaced text at (453.696533203125, 132.71182250976562) with 'là'
# Replaced text at (471.0812683105469, 132.71182250976562) with 'không'
# Replaced text at (129.4423828125, 146.37948608398438) with 'Tuy nhiên, đặc biệt hạn chế, một đơn vị lặp lại được đại diện'
# Replaced text at (129.45680236816406, 159.73556518554688) with 'bởi công thức chung sau đây (1)'
# Replaced text at (361.2455139160156, 159.73452758789062) with 'là'
# Replaced text at (375.85009765625, 159.73452758789062) with 'ưa thích.'
# Replaced text at (130.78797912597656, 200.49021911621094) with '[Chem. 22]'
# Replaced text at (691.288818359375, 86.96192932128906) with '34'
# Replaced text at (520.7904663085938, 105.68905639648438) with 'nhóm alkoxy, một nhóm carboxyl, một nhóm alkoxycarbonyl,'
# Replaced text at (520.8048706054688, 118.41067504882812) with 'một nhóm alkylcarbonyl, một nhóm alkylcarbonyloxy,'
# Replaced text at (520.8192749023438, 131.46627807617188) with 'Nhóm alkylsulfonyloxy và một nhóm arylcarbonyl.'
# Replaced text at (535.755859375, 144.51071166992188) with 'Đơn vị lặp lại có nhóm hydroxyl phenolic'
# Replaced text at (871.7357177734375, 144.51486206054688) with 'là'
# Replaced text at (502.70220947265625, 160.09849548339844) with '5'
# Replaced text at (520.5057373046875, 157.23678588867188) with 'Tốt hơn là một đơn vị lặp lại được đại diện bởi phần sau-'
# Replaced text at (520.8082885742188, 170.29238891601562) with 'ing công thức chung (2) vì những lý do'
# Replaced text at (783.2708740234375, 170.29519653320312) with 'của'
# Replaced text at (803.3856201171875, 170.29519653320312) with 'liên kết ngang'
# Replaced text at (520.52783203125, 183.02798461914062) with 'phản ứng, khả năng phát triển và'
# Replaced text at (703.2974243164062, 183.34164428710938) with 'xoay'
# Replaced text at (728.2022094726562, 183.02999877929688) with 'Kháng khắc.'
# Replaced text at (309.0743408203125, 229.0059814453125) with '11'
# Replaced text at (478.1993408203125, 223.16453552246094) with '(l)'
# Replaced text at (500.4747009277344, 223.16453552246094) with '10 [Hóa học. 23]'
# Replaced text at (265.71282958984375, 241.6514892578125) with '~'
# Replaced text at (309.476318359375, 270.62713623046875) with 'B1'
# Replaced text at (311.4693603515625, 278.6460266113281) with 'TÔI'
# Replaced text at (308.7226257324219, 291.419677734375) with 'AR'
# Replaced text at (311.368896484375, 296.38287353515625) with 'TÔI'
# Replaced text at (306.0763854980469, 312.92041015625) with '(OH) M1'
# Replaced text at (500.4747009277344, 289.3235778808594) with '15'
# Replaced text at (702.1752319335938, 252.3013916015625) with '12'
# Replaced text at (659.232421875, 264.6363525390625) with '~'
# Replaced text at (701.8402709960938, 293.90447998046875) with 'AR'
# Replaced text at (704.8717041015625, 298.32415771484375) with 'TÔI'
# Replaced text at (702.1082763671875, 312.12799072265625) with 'Ồ'
# Replaced text at (869.2569580078125, 244.02310180664062) with '(2)'
# Replaced text at (145.00735473632812, 342.3709411621094) with 'Trong công thức chung'
# Replaced text at (288.05517578125, 342.3709411621094) with '(1'
# Replaced text at (300.18096923828125, 342.3709411621094) with ')'
# Replaced text at (535.7131958007812, 341.7367858886719) with 'Trong công thức chung (2),'
# Replaced text at (145.0408477783203, 355.4544677734375) with 'Ru'
# Replaced text at (171.62051391601562, 355.7270202636719) with 'đại diện cho một nguyên tử hydro, một nhóm methyl'
# Replaced text at (499.97222900390625, 353.9295959472656) with '20'
# Replaced text at (535.7467651367188, 354.31451416015625) with 'R'
# Replaced text at (546.4824829101562, 361.6634826660156) with '12'
# Replaced text at (562.326416015625, 354.4845886230469) with 'đại diện cho một nguyên tử hydro'
# Replaced text at (736.2581787109375, 354.4845886230469) with 'hoặc'
# Replaced text at (753.9276733398438, 354.4845886230469) with 'một nhóm methyl;'
# Replaced text at (535.3782958984375, 367.5300598144531) with 'AR'
# Replaced text at (556.2969970703125, 367.5300598144531) with 'đại diện cho một vòng thơm; Và'
# Replaced text at (159.54991149902344, 369.3887634277344) with 'có thể có một nhóm thế,'
# Replaced text at (309.7778015136719, 369.3937072753906) with 'hoặc'
# Replaced text at (327.4472961425781, 369.3937072753906) with 'một nguyên tử halogen;'
# Replaced text at (145.04017639160156, 383.0613708496094) with 'B'
# Replaced text at (155.25735473632812, 390.17864990234375) with '1'
# Replaced text at (165.1891326904297, 383.0603332519531) with 'đại diện cho một trái phiếu duy nhất'
# Replaced text at (318.6209411621094, 383.0603332519531) with 'hoặc'
# Replaced text at (336.2904357910156, 383.0603332519531) with 'một nhóm liên kết hóa trị hai;'
# Replaced text at (144.67237854003906, 396.4164123535156) with 'AR'
# Replaced text at (165.1891326904297, 396.4164123535156) with 'đại diện cho một vòng thơm; Và'
# Replaced text at (144.67237854003906, 410.0830993652344) with 'ml'
# Replaced text at (168.80679321289062, 410.0830993652344) with 'Lặp lại một số nguyên'
# Replaced text at (300.91790771484375, 410.0830993652344) with 'của'
# Replaced text at (319.4583435058594, 410.0830993652344) with '1'
# Replaced text at (331.0816955566406, 410.0830993652344) with 'hoặc'
# Replaced text at (348.0645751953125, 410.0830993652344) with 'Hơn.'
# Replaced text at (144.67138671875, 423.7507629394531) with 'Như một nhóm methyl có thể có một nhóm thế trong'
# Replaced text at (465.8055419921875, 423.4771728515625) with 'Ru,'
# Replaced text at (129.68260192871094, 437.1058044433594) with 'một nhóm trifluoromethyl, một nhóm hydroxymethyl và'
# Replaced text at (129.66822814941406, 450.7734680175781) with 'được bao gồm.'
# Replaced text at (145.0408477783203, 464.1666259765625) with 'Ru'
# Replaced text at (170.31414794921875, 464.4391784667969) with 'là'
# Replaced text at (184.1147918701172, 464.4391784667969) with 'Tốt nhất và nguyên tử hydro'
# Replaced text at (356.4052429199219, 464.4391784667969) with 'hoặc'
# Replaced text at (372.868896484375, 464.4391784667969) with 'và nhóm methyl và'
# Replaced text at (129.6929931640625, 477.7951965332031) with 'Một nguyên tử hydro là thích hợp hơn vì lý do'
# Replaced text at (419.496337890625, 477.7951965332031) with 'của'
# Replaced text at (438.0032653808594, 477.7951965332031) with 'có thể phát triển'
# Replaced text at (129.6798858642578, 491.4628601074219) with 'Khả năng.'
# Replaced text at (144.6740264892578, 505.1305236816406) with 'Như nhóm liên kết hóa trị hai'
# Replaced text at (326.2414245605469, 505.1285095214844) with 'của'
# Replaced text at (342.8055419921875, 505.1285095214844) with 'BI, một nhóm carbonyl, một'
# Replaced text at (129.68994140625, 518.4845581054688) with 'nhóm alkylene (tốt nhất là 1 đến'
# Replaced text at (327.49755859375, 518.4845581054688) with '10'
# Replaced text at (346.3562316894531, 518.4845581054688) with 'nguyên tử carbon và hơn thế nữa'
# Replaced text at (129.4524383544922, 531.5289306640625) with 'tốt nhất là 1 đến 5), một nhóm sulfonyl'
# Replaced text at (348.28228759765625, 531.530029296875) with '(-S (= o)'
# Replaced text at (412.34478759765625, 538.9175415039062) with '2'
# Replaced text at (417.436279296875, 536.4326782226562) with '-),'
# Replaced text at (445.5567932128906, 531.530029296875) with '--- 0-,'
# Replaced text at (129.1634063720703, 543.9542236328125) with '-NH-'
# Replaced text at (181.97923278808594, 543.9542236328125) with 'hoặc một nhóm liên kết hóa trị hai kết hợp'
# Replaced text at (129.71609497070312, 557.29736328125) with 'là'
# Replaced text at (144.72264099121094, 557.29736328125) with 'ưa thích.'
# Replaced text at (145.03952026367188, 570.0413208007812) with 'B'
# Replaced text at (155.25735473632812, 577.461181640625) with '1'
# Replaced text at (167.23243713378906, 570.045166015625) with 'Tốt hơn là đại diện cho một trái phiếu duy nhất, một carbonloxy'
# Replaced text at (129.7110595703125, 583.089599609375) with 'Nhóm'
# Replaced text at (169.40972900390625, 583.0906372070312) with '(-C (= o) --- 0-),'
# Replaced text at (288.84234619140625, 583.0906372070312) with 'hoặc ---- c (= o) -nh-,'
# Replaced text at (426.0449523925781, 583.0906372070312) with 'Thêm pref-'
# Replaced text at (129.6765594482422, 596.1239013671875) with 'đại diện cho một liên kết duy nhất, một nhóm carbonloxy'
# Replaced text at (460.8982849121094, 596.1231689453125) with '(----C'
# Replaced text at (129.98406982421875, 608.8709106445312) with '(= 0) -0-),'
# Replaced text at (220.92770385742188, 608.8709106445312) with 'và đặc biệt tốt nhất là một trái phiếu duy nhất'
# Replaced text at (129.70970153808594, 621.915283203125) with 'từ chế độ xem'
# Replaced text at (243.43751525878906, 621.9163818359375) with 'của'
# Replaced text at (260.0351257324219, 621.9163818359375) with 'sự cải thiện'
# Replaced text at (368.04534912109375, 621.9163818359375) with 'của'
# Replaced text at (384.9444580078125, 621.9163818359375) with 'resis khắc khô-'
# Replaced text at (129.3958740234375, 634.6380615234375) with 'Tanta.'
# Replaced text at (144.67237854003906, 647.6966552734375) with 'MỘT'
# Replaced text at (171.4865264892578, 647.6966552734375) with 'vòng thơm'
# Replaced text at (265.54534912109375, 647.6966552734375) with 'của'
# Replaced text at (285.3586730957031, 647.6966552734375) with 'AR'
# Replaced text at (309.7945251464844, 647.6966552734375) with 'là monocyclic'
# Replaced text at (407.0522766113281, 647.6966552734375) with 'hoặc'
# Replaced text at (427.7030334472656, 647.6966552734375) with 'đa vòng'
# Replaced text at (129.67822265625, 660.429443359375) with 'vòng thơm, và bao gồm một vòng hydrocarbon thơm'
# Replaced text at (129.41897583007812, 673.4627685546875) with 'có 6 đến'
# Replaced text at (212.1348114013672, 673.4640502929688) with '18'
# Replaced text at (233.4052276611328, 673.4640502929688) with 'Các nguyên tử carbon như vậy'
# Replaced text at (359.20220947265625, 673.4640502929688) with 'BẰNG'
# Replaced text at (378.8982849121094, 673.4640502929688) with 'một vòng benzen, một'
# Replaced text at (129.41358947753906, 686.5084228515625) with 'vòng naphthalene, vòng anthracene, vòng fluorene hoặc một'
# Replaced text at (129.47122192382812, 699.2412109375) with 'vòng phenanthren, có thể có một nhóm thế hoặc, cho'
# Replaced text at (129.716064453125, 712.28564453125) with 'ví dụ, một vòng dị vòng vòng thơm có một dị vòng'
# Replaced text at (130.06178283691406, 725.0184326171875) with 'như là'
# Replaced text at (164.25123596191406, 725.024658203125) with 'BẰNG'
# Replaced text at (183.5453338623047, 725.024658203125) with 'một vòng thiophene, một vòng furan, một vòng pyrrole, một'
# Replaced text at (129.4742889404297, 738.069091796875) with 'Vòng benzothiophene, vòng benzofuran, vòng benzopyrrole,'
# Replaced text at (129.6903533935547, 751.113525390625) with 'Trong vòng triazine, trong vòng imeidazole, trong vòng benzoimidazole, a'
# Replaced text at (129.4022979736328, 763.8462524414062) with 'Vòng tròn triazole, trong vòng thiadiazole'
# Replaced text at (328.6699523925781, 763.8504028320312) with 'hoặc'
# Replaced text at (346.7414245605469, 763.8504028320312) with 'một chiếc nhẫn thiazole. Giữa'
# Replaced text at (129.39117431640625, 776.8948364257812) with 'Đây, một vòng benzen và vòng naphthalene thích hợp hơn'
# Replaced text at (129.67926025390625, 789.6276245117188) with 'từ quan điểm'
# Replaced text at (249.4669189453125, 789.6307373046875) with 'của'
# Replaced text at (265.6793518066406, 789.6307373046875) with 'độ phân giải và một vòng benzen'
# Replaced text at (447.6670837402344, 789.6307373046875) with 'là'
# Replaced text at (461.41748046875, 789.6307373046875) with 'Chán ngấy'
# Replaced text at (129.4434051513672, 802.6751098632812) with 'thích hợp hơn từ quan điểm'
# Replaced text at (318.6041564941406, 802.6761474609375) with 'của'
# Replaced text at (336.2402038574219, 802.6761474609375) with 'Sự nhạy cảm.'
# Replaced text at (144.67237854003906, 815.4239501953125) with 'ml'
# Replaced text at (167.90237426757812, 815.4239501953125) with 'tốt nhất là một số nguyên'
# Replaced text at (311.368896484375, 815.4239501953125) with 'của'
# Replaced text at (328.70343017578125, 815.4239501953125) with '1 đến'
# Replaced text at (355.1323547363281, 815.4239501953125) with '5,'
# Replaced text at (370.0551452636719, 815.4239501953125) with 'và tốt nhất là'
# Replaced text at (499.97222900390625, 418.6719665527344) with '25'
# Replaced text at (535.7467651367188, 380.0948486328125) with 'R'
# Replaced text at (546.4824829101562, 387.7543640136719) with '12'
# Replaced text at (561.5224609375, 380.2649230957031) with 'đại diện cho một nguyên tử hydro'
# Replaced text at (733.04248046875, 380.2649230957031) with 'hoặc'
# Replaced text at (749.9080810546875, 380.2649230957031) with 'một nhóm methyl và là'
# Replaced text at (550.7064208984375, 393.3092956542969) with 'tốt nhất là một nguyên tử hydro vì lý do'
# Replaced text at (812.2120361328125, 393.3103332519531) with 'của'
# Replaced text at (829.1111450195312, 393.3103332519531) with 'có thể phát triển'
# Replaced text at (550.9344482421875, 406.0431213378906) with 'Khả năng.'
# Replaced text at (535.3782958984375, 419.0906677246094) with 'AR'
# Replaced text at (557.8043212890625, 419.0906677246094) with 'Trong công thức chung (2)'
# Replaced text at (728.2357177734375, 419.0906677246094) with 'là'
# Replaced text at (743.9959106445312, 419.0906677246094) with 'giống như'
# Replaced text at (823.1821899414062, 419.0906677246094) with 'AR'
# Replaced text at (845.6082763671875, 419.0906677246094) with 'trong'
# Replaced text at (520.8215942382812, 432.1350402832031) with 'Công thức chung (1) và giống như phạm vi ưa thích. Các'
# Replaced text at (520.5191650390625, 444.8678283691406) with 'Đơn vị lặp lại được biểu thị bằng công thức chung (2) là'
# Replaced text at (520.5624389648438, 457.9122619628906) with 'tốt nhất là một đơn vị lặp lại được tạo ra từ hydrox-'
# Replaced text at (520.5191650390625, 470.6339416503906) with 'Ystyrene (nghĩa là trong công thức chung (2), một đơn vị lặp lại'
# Replaced text at (499.9219665527344, 482.9674377441406) with '30'
# Replaced text at (520.5225219726562, 483.6966857910156) with 'Trong đó r'
# Replaced text at (584.9701538085938, 491.0712585449219) with '12'
# Replaced text at (601.2161254882812, 483.6966857910156) with 'là'
# Replaced text at (616.0551147460938, 483.6966857910156) with 'và nguyên tử hydro và'
# Replaced text at (750.4273071289062, 483.6966857910156) with 'AR'
# Replaced text at (771.6475219726562, 483.6966857910156) with 'là'
# Replaced text at (786.4865112304688, 483.6966857910156) with 'một vòng benzen)'
# Replaced text at (520.783447265625, 496.4294738769531) with 'từ quan điểm'
# Replaced text at (643.3884887695312, 496.4315490722656) with 'của'
# Replaced text at (661.426513671875, 496.4315490722656) with 'Sự nhạy cảm.'
# Replaced text at (535.697509765625, 509.4648742675781) with 'Các hợp chất'
# Replaced text at (637.7275390625, 509.4640197753906) with '(BL)'
# Replaced text at (672.3296508789062, 509.4640197753906) with 'BẰNG'
# Replaced text at (692.0257568359375, 509.4640197753906) with 'một hợp chất polymer có thể là'
# Replaced text at (520.810302734375, 522.5195922851562) with 'được cấu hình từ chỉ một đơn vị lặp lại có phenolic'
# Replaced text at (520.53662109375, 535.2523803710938) with 'Nhóm hydroxyl như mô tả ở trên. Các hợp chất'
# Replaced text at (837.5020141601562, 535.25732421875) with '(BL)'
# Replaced text at (869.29052734375, 535.25732421875) with 'BẰNG'
# Replaced text at (499.9219665527344, 547.4242553710938) with '35'
# Replaced text at (520.7904663085938, 548.289794921875) with 'một hợp chất polymer có thể có một đơn vị lặp lại như mô tả'
# Replaced text at (520.7904663085938, 561.0225830078125) with 'sau này ngoài một đơn vị lặp lại có hydroxyl phenolic'
# Replaced text at (520.804931640625, 574.078125) with 'Nhóm'
# Replaced text at (561.7904663085938, 574.0830688476562) with 'BẰNG'
# Replaced text at (580.2974243164062, 574.0830688476562) with 'mô tả ở trên. Trong trường hợp này, nội dung'
# Replaced text at (845.1727905273438, 574.0830688476562) with 'của'
# Replaced text at (862.976318359375, 574.0830688476562) with 'các'
# Replaced text at (520.5164794921875, 587.1163330078125) with 'Lặp lại đơn vị có nhóm hydroxyl phenolic'
# Replaced text at (825.9121704101562, 587.1155395507812) with 'là'
# Replaced text at (840.918701171875, 587.1155395507812) with 'thích hơn'
# Replaced text at (520.784423828125, 599.8483276367188) with 'ably từ'
# Replaced text at (587.9681396484375, 599.8504028320312) with '10'
# Replaced text at (607.3292236328125, 599.8504028320312) with 'đến 98% bởi mo !, tốt hơn là từ 30 đến'
# Replaced text at (499.5870361328125, 612.0432739257812) with '40'
# Replaced text at (521.1756591796875, 612.9088134765625) with '97% bởi mo !, Và thậm chí tốt hơn là từ'
# Replaced text at (799.0477905273438, 613.0451049804688) with '40'
# Replaced text at (817.9567260742188, 612.9088134765625) with 'đến 95% bởi'
# Replaced text at (520.5224609375, 625.6416015625) with 'Khối lượng, đối với tổng số đơn vị lặp lại'
# Replaced text at (809.3982543945312, 625.6436767578125) with 'của'
# Replaced text at (826.7998657226562, 625.6436767578125) with 'com-'
# Replaced text at (520.5505981445312, 638.6769409179688) with 'pound (b'
# Replaced text at (577.5171508789062, 638.6761474609375) with '1)'
# Replaced text at (592.3394775390625, 638.6761474609375) with 'như một hợp chất polymer. Do đó, đặc biệt là trong'
# Replaced text at (520.782470703125, 651.408935546875) with 'một trường hợp trong đó màng kháng chiến là một màng mỏng (ví dụ, trong một'
# Replaced text at (520.7968139648438, 664.4644775390625) with 'trường hợp độ dày'
# Replaced text at (673.9375610351562, 664.4694213867188) with 'của'
# Replaced text at (690.1331787109375, 664.4694213867188) with 'bộ phim chống lại'
# Replaced text at (777.27490234375, 664.4694213867188) with 'là'
# Replaced text at (791.31005859375, 664.4694213867188) with 'Từ 10 đến 150'
# Replaced text at (499.5870361328125, 676.6364135742188) with '45'
# Replaced text at (520.5225219726562, 677.501953125) with 'nm), tỷ lệ hòa tan'
# Replaced text at (671.927734375, 677.501953125) with 'của'
# Replaced text at (688.1233520507812, 677.501953125) with 'phần tiếp xúc trong điện trở'
# Replaced text at (520.7968139648438, 690.245849609375) with 'phim ảnh'
# Replaced text at (548.5257568359375, 690.2496948242188) with 'của'
# Replaced text at (564.7213745117188, 690.2496948242188) with 'sáng chế được hình thành bằng cách sử dụng hợp chất'
# Replaced text at (521.1756591796875, 703.295166015625) with '(B'
# Replaced text at (536.5171508789062, 703.295166015625) with '1)'
# Replaced text at (551.4734497070312, 703.295166015625) with 'Đối với một nhà phát triển kiềm có thể đáng tin cậy hơn'
# Replaced text at (520.7938232421875, 716.0279541015625) with 'giảm (điều đó'
# Replaced text at (615.2847290039062, 716.030029296875) with 'là'
# Replaced text at (628.6331787109375, 716.030029296875) with 'Tỷ lệ hòa tan'
# Replaced text at (747.0943603515625, 716.030029296875) with 'của'
# Replaced text at (763.2900390625, 716.030029296875) with 'phim chống lại sử dụng'
# Replaced text at (520.5029907226562, 729.074462890625) with 'các hợp chất'
# Replaced text at (614.8157958984375, 729.075439453125) with '(BL)'
# Replaced text at (647.8267822265625, 729.075439453125) with 'có thể được kiểm soát một cách đáng tin cậy hơn để được'
# Replaced text at (499.88848876953125, 741.2554321289062) with '50'
# Replaced text at (520.8071899414062, 741.810302734375) with 'tối ưu). Kết quả là, độ nhạy có thể đáng tin cậy hơn'
# Replaced text at (520.821533203125, 754.854736328125) with 'tăng.'
# Replaced text at (499.88848876953125, 805.8485107421875) with '55'
# Replaced text at (535.7467651367188, 767.9012451171875) with 'Infit, ví dụ'
# Replaced text at (681.1727905273438, 767.9012451171875) with 'của'
# Replaced text at (702.1920166015625, 767.9012451171875) with 'đơn vị lặp lại có một'
# Replaced text at (520.5482788085938, 780.634033203125) with 'Nhóm hydroxyl phenolic sẽ được mô tả, nhưng hiện tại'
# Replaced text at (520.8219604492188, 793.6784057617188) with 'sự phát minh'
# Replaced text at (582.7258911132812, 793.6815185546875) with 'là'
# Replaced text at (597.2969970703125, 793.6815185546875) with 'Không giới hạn.'
# Replaced text at (130.5702667236328, 828.4564819335938) with '1.'
# Replaced text at (145.86151123046875, 828.4564819335938) with 'Trong khi'
# Replaced text at (186.87828063964844, 828.4564819335938) with 'ml'
# Replaced text at (211.3141326904297, 828.4564819335938) with 'là 1 và'
# Replaced text at (264.8586730957031, 828.4564819335938) with 'AR'
# Replaced text at (286.4808044433594, 828.4564819335938) with 'là'
# Replaced text at (301.7218017578125, 828.4564819335938) with 'một vòng benzen, vị trí'
# Replaced text at (478.1826171875, 828.4564819335938) with 'của'
# Replaced text at (130.03431701660156, 841.2042236328125) with 'thay thế'
# Replaced text at (205.6531982421875, 841.2042236328125) with 'của'
# Replaced text at (223.6576690673828, 841.2042236328125) with '-Ồ'
# Replaced text at (266.86846923828125, 841.2042236328125) with 'có thể là vị trí para, meta-'
# Replaced text at (129.44374084472656, 854.2486572265625) with 'vị trí, hoặc vị trí ortho liên quan đến liên kết'
# Replaced text at (129.44374084472656, 867.2930908203125) with 'chức vụ'
# Replaced text at (181.53553771972656, 867.295166015625) with 'của'
# Replaced text at (197.21202087402344, 867.295166015625) with 'A Benzen Ring to B'
# Replaced text at (312.42401123046875, 871.9302368164062) with '1 ('
# Replaced text at (325.8394775390625, 867.295166015625) with 'một chuỗi chính polymer khi'
# Replaced text at (500.30718994140625, 870.293212890625) with '60'
# Replaced text at (129.76634216308594, 880.030029296875) with 'B'
# Replaced text at (140.3848114013672, 887.4589233398438) with '1'
# Replaced text at (150.21609497070312, 880.030029296875) with 'là'
# Replaced text at (164.65318298339844, 880.030029296875) with 'một trái phiếu duy nhất), tuy nhiên từ quan điểm'
# Replaced text at (437.5845642089844, 880.030029296875) with 'của'
# Replaced text at (454.8856506347656, 880.030029296875) with 'Đi qua-'
# Replaced text at (129.71006774902344, 893.074462890625) with 'liên kết phản ứng, vị trí para và vị trí meta'
# Replaced text at (129.68125915527344, 905.8072509765625) with 'được ưa thích và vị trí para'
# Replaced text at (351.59844970703125, 905.810302734375) with 'là'
# Replaced text at (366.15277099609375, 905.810302734375) with 'Ưa thích hơn.'
# Replaced text at (829.7978515625, 834.1137084960938) with '[Chem. 24]'
# Replaced text at (144.9906005859375, 918.8557739257812) with 'Vòng thơm'
# Replaced text at (255.89828491210938, 918.8557739257812) with 'của'
# Replaced text at (271.2900390625, 918.8557739257812) with 'AR'
# Replaced text at (290.58416748046875, 918.8557739257812) with 'cũng có thể có một nhóm khác'
# Replaced text at (129.39349365234375, 931.9002075195312) with 'hơn một nhóm được đại diện bởi'
# Replaced text at (314.5008239746094, 931.9012451171875) with '-Ồ'
# Replaced text at (358.4150390625, 931.9012451171875) with 'được mô tả ở trên, và'
# Replaced text at (500.30718994140625, 934.8992919921875) with '65'
# Replaced text at (129.68260192871094, 944.6361083984375) with 'kỳ thi'
# Replaced text at (195.6041717529297, 944.6361083984375) with 'của'
# Replaced text at (217.42730712890625, 944.6361083984375) with 'Các nhóm thế bao gồm một nhóm alkyl,'
# Replaced text at (129.7094268798828, 957.6693725585938) with 'Nhóm cycloalkyl và nhóm halogen và nhóm hydroxyl,'
# Replaced text at (600.01025390625, 946.3726196289062) with 'Ồ'
# Replaced text at (832.7405395507812, 946.3726196289062) with 'Ồ'
# PDF scaled successfully to 612.0x792.0.
# Both page dimensions and content have been scaled. Saved to ./translation_8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.pdf
# PDF modified and saved as ./translation_8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01.pdf
# Deleted temporary folder: ./8a901ba1819cf193c881e8899f758d1a135a14c85d5c89fdf85454eca20abe01
